# %% [markdown]
# <a href="https://colab.research.google.com/github/guinb/atlantico_avanti_bootcamp/blob/main/Atividade2_Modulo2_Guilherme_Nogueira_Batistette.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Questões

# %% [markdown]
# Conteúdo: Módulo 2;
# Lista de exercícios: 10 questões;
# Peso: 25% da nota final;
# Equipes: máximo de 2 alunos;
# Entrega: até 16/08/2;
#
# ---
#
# 1.	Utilizando o matplotlib, crie e mostre um gráfico de linha simples e adicione títulos aos eixos X e Y do gráfico.
#
# 2.	Utilizando o matplotlib, utilize a função subplot() para mostrar 6 gráficos.
#
# 3.	Complete o código:
# ```
# import matplotlib.pyplot as plt
# names = ['group_a', 'group_b', 'group_c']
# values = [1, 10, 100]
# ___.figure(figsize=(9, 3))
# plt.subplot(131)
# plt.bar(__, ___)
# plt.subplot(132)
# plt.scatter(__, __)
# plt.subplot(___)
# plt.plot(names, values)
# plt.suptitle('Categorical Plotting')
# plt.____()
# ```
#
#
#
# 4.	Complete o código:
# ```
# import __________.pyplot as plt
# import numpy as ___
# fig, axs = plt.subplots(ncols=2, nrows=2, figsize=(5.5, 3.5),
# layout="constrained")
# for ___ in range(2):
# for ___ in range(2):
# axs[row, col].annotate(f'axs[{row}, {col}]', (0.5, 0.5),
# transform=axs[row, col].transAxes,
# ha='center', va='center', ________=18,
# color='darkgrey')
# fig.suptitle('__.subplots()')
# ```
#
# 5.	Complete o código:
# ```
# import numpy as np
# import __________ as mpl
# import __________.______ as plt
# x = np.________(-2 * np.pi, 2 * np.pi, 100)
# y = np.____(x)
# __, __ = plt.subplots()
# ax.____(_, _)
# ```
#
# 6.	Utilizando pandas, como realizar a leitura de um arquivo CSV em um DataFrame e exibir as primeiras linhas?
#
# 7.	Utilizando pandas, como selecionar uma coluna específica e filtrar linhas em um “DataFrame” com base em uma condição?
#
# 8.	Utilizando pandas, como lidar com valores ausentes (NaN) em um DataFrame?
#
# 9.	Utilizando pandas, como remover uma coluna de um DataFrame?
#
# 10.	Utilizando pandas, mostre uma forma de detectar e tratar valores outliers em um DataFrame.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import string

SEED = 123
np.random.seed(SEED)
plt.style.use('fivethirtyeight')

# %%
df_base = pd.DataFrame({
    "coluna": list(np.random.standard_normal(size=26)),
    "coluna2": list(string.ascii_lowercase)
})
df_base.to_csv('ex.csv', index=False)

# %% [markdown]
# #1

# %%
fig = plt.figure(figsize=(10,5))
eixo = fig.add_axes([0,0,1,1])

x = np.linspace(-1, 1, 100)
y = np.sin(2 * x)

eixo.plot(x, y, linewidth=3.0)
eixo.set_title('Título', fontsize=25)
eixo.set_xlabel('Eixo X', fontsize=15)
eixo.set_ylabel('Eixo Y', fontsize=15)
plt.show()

# %% [markdown]
# #2

# %%
fig, axs = plt.subplots(2, 3, figsize=(12, 8), layout='constrained')

x = np.linspace(-1, 1, 100)
y = np.sin(2 * x)
cont = 0.5

for ax in axs.flat:
  ax.set_title('Título')
  ax.set_xlabel('Eixo X')
  ax.set_ylabel('Eixo Y')
  ax.plot(x, y, linewidth = cont)
  cont+=0.5

# %% [markdown]
# #3

# %%
import matplotlib.pyplot as plt

names = ['group_a', 'group_b', 'group_c']
values = [1, 10, 100]

plt.figure(figsize=(9, 3))

plt.subplot(131)
plt.bar(names, values)

plt.subplot(132)
plt.scatter(names, values)

plt.subplot(133)
plt.plot(names, values)

plt.suptitle('Categorical Plotting')
plt.show()

# %% [markdown]
# #4

# %%
import matplotlib.pyplot as plt
import numpy as np

fig, axs = plt.subplots(ncols=2, nrows=2, figsize=(5.5, 3.5),
layout="constrained")

for row in range(2):
    for col in range(2):
        axs[row, col].annotate(f'axs[{row}, {col}]', (0.5, 0.5),
                               transform=axs[row, col].transAxes,
                               ha='center', va='center', rotation=18,
                               color='darkgrey')
fig.suptitle('axs.subplots()')
# Out:
# Text(0.5, 0.98, 'axs.subplots()')

# %% [markdown]
# #5

# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

x = np.linspace(-2 * np.pi, 2 * np.pi, 100)
y = np.sin(x)

fig, ax = plt.subplots()
ax.plot(x, y)

# %% [markdown]
# #6

# %%
df = pd.read_csv("ex.csv")
df.head()
# Out:
#      coluna coluna2
# 0 -1.085631       a
# 1  0.997345       b
# 2  0.282978       c
# 3 -1.506295       d
# 4 -0.578600       e

# %% [markdown]
# #7

# %%
# df["coluna"]
# df[df["coluna"] > 0]
# df.loc[df["coluna"] > 0]
# df.query("coluna > 0")
df[(df["coluna"] > 0) & (df["coluna2"] > "s")]
# Out:
#       coluna coluna2
# 19  0.386186       t
# 20  0.737369       u
# 21  1.490732       v
# 23  1.175829       x

# %% [markdown]
# #8

# %%
df[df.isna()]
df["coluna"].fillna(0, inplace = True)
df.dropna(subset = ["coluna2"], inplace = True)

# %% [markdown]
# #9

# %%
df2 = df.copy()
df2.drop(columns="coluna2")
df2.drop("coluna2", axis = 1, inplace = True)

# %% [markdown]
# #10

# %%
df.loc[len(df)] = [-4.5,'a']
df.loc[len(df)] = [4.5,'z']
df.boxplot(['coluna'])
# Out:
# <Axes: >

# %%
Q1 = df['coluna'].quantile(.25)
Q3 = df['coluna'].quantile(.75)
IIQ = Q3 - Q1
limite_inferior = Q1 - 1.5 * IIQ
limite_superior = Q3 + 1.5 * IIQ
print(f"Q1: {Q1}, Q3: {Q3}, IIQ: {IIQ}\nLimite inferior: {limite_inferior}, Limite superior: {limite_superior}")
# Out:
# Q1: -0.7258497142828162, Q3: 1.198355848262961, IIQ: 1.9242055625457772
# Limite inferior: -3.612158058101482, Limite superior: 4.084664192081627

# %%
filtro = (df["coluna"] >= limite_inferior) & (df["coluna"] <= limite_superior)
outliers = df[filtro == False].copy()
df_sem_outliers = df[filtro == True].copy()
df_sem_outliers
# Out:
#       coluna coluna2
# 0  -1.085631       a
# 1   0.997345       b
# 2   0.282978       c
# 3  -1.506295       d
# 4  -0.578600       e
# 5   1.651437       f
# 6  -2.426679       g
# 7  -0.428913       h
# 8   1.265936       i
# 9  -0.866740       j
# 10 -0.678886       k
# 11 -0.094709       l
# 12  1.491390       m
# 13 -0.638902       n
# 14 -0.443982       o
# 15 -0.434351       p
# 16  2.205930       q
# 17  2.186786       r
# 18  1.004054       s
# 19  0.386186       t
# 20  0.737369       u
# 21  1.490732       v
# 22 -0.935834       w
# 23  1.175829       x
# 24 -1.253881       y
# 25 -0.637752       z

# %%
outliers
# Out:
#     coluna coluna2
# 26    -4.5       a
# 27     4.5       z
